# %% [markdown]
# # 5 Number Summary and Box Plot

# %%
## Minimum, Maximum, Median, Q1, Q3, IQR

# %%
import numpy as np

# %%
lst_marks = [45,65,34,23,56,76,86,46,66,60,87,42.98,99,74,67]
minimum,Q1,median,Q3,Maximum = np.quantile(lst_marks, [0, 0.25, 0.50, 0.75, 1.0])

# %%
minimum, Q1, median, Q3, Maximum
# Out:
# (23.0, 45.5, 65.0, 75.0, 99.0)

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 29.5

# %%
lower_fence = Q1 - 1.5*(IQR)
higher_fence = Q3 + 1.5*(IQR)

# %%
lower_fence
# Out:
# 1.25

# %%
higher_fence
# Out:
# 119.25

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks = [-100,-50,45,65,34,23,56,76,86,46,66,60,87,42.98,99,74,67,150,170,180]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
