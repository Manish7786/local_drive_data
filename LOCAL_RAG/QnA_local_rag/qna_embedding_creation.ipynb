# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from tqdm.auto import tqdm

# %%
# Load the Excel file
excel_path = "ccares_qna_dataset.xlsx"
query_df = pd.read_excel(excel_path)

# %%
query_df.head()
# Out:
#                        Section  \
# 0  Paragraph 1, Subparagraph 2
# 1  Paragraph 1, Subparagraph 2
# 2  Paragraph 1, Subparagraph 2
# 3  Paragraph 1, Subparagraph 2
# 4  Paragraph 1, Subparagraph 2
#
#                                                Query  \
# 0  To which regions does the Coal Mines Provident...
# 1  Under which act is the Coal Mines Provident Fu...
# 2  What legal provision facilitates the applicati...
# 3  Does the scheme include coal mines in partiall...
# 4  Which provinces are explicitly mentioned as be...
#
#                                               Answer
# 0  The scheme applies to all coal mines in West B...
# 1  The scheme is governed by the Coal Mines Provi...
# 2  The scheme is applied under Sub-section (1) of...
# 3  Yes, the scheme includes coal mines in partial...
# 4  The provinces explicitly mentioned are West Be...

# %%
# Initialize the Sentence Transformer model
embedding_model = SentenceTransformer("all-mpnet-base-v2", device="cpu")

# %%
# Extract the "Query" column
queries = query_df["Query"].tolist()

# %%
queries
# Out:
# ['To which regions does the Coal Mines Provident Fund Scheme apply?',
#  'Under which act is the Coal Mines Provident Fund Scheme governed?',
#  'What legal provision facilitates the application of the Coal Mines Provident Fund Scheme?',
#  'Does the scheme include coal mines in partially excluded areas?',
#  'Which provinces are explicitly mentioned as being covered under the Coal Mines Provident Fund Scheme?',
#  "Which Indian provinces are mentioned as part of the Coal Mines Provident Fund Scheme's applicability?",
#  'What does Sub-section (1) of Section 92 of the Government of India Act, 1935, relate to in the context of the scheme?',
#  'Is Maharashtra explicitly included under the Coal Mines Provident Fund Scheme?',
#  'Which act is cited in the passage as governing the provident fund scheme for coal mines?',
#  'Are partially excluded areas included in the applicability of the scheme?',
#  'What is the purpose of the Coal Mines Provident Fund and Miscellaneous Provisions Act, 1948, in this context?',
#  'Does the scheme apply to coal mines in Nagaland?',
#  'Which historical act is referenced in the passage to define the application of the scheme?',
#  'Are the Central Provinces and Berar included in the Coal Mines Provident Fund Scheme?',
#  'Is Orissa explicitly mentioned in the passage, and under what context?',
#  "When was the word 'Bombay' substituted by the word 'Maharashtra'?",
#  'Which notification introduced the insertion of the words "West Bengal"?',
#  'When was the word "Nagaland" added?',
#  'What does S.R.O. 3566 dated 31.10.57 pertain to in the context of the passage?',
#  'When was the substitution of the subparagraph, excluding the words "West Bengal," made?',
#  'What does G.S.R. 690 dated 25.4.1964 signify in the passage?',
#  'What date was the word "Maharashtra" officially published as a replacement for "Bombay"?',
#  'Which Ministry was responsible for the notifications mentioned in the passage?',
#  'What exception is noted in the substitution of the subparagraph under the 9 February 1950 notification?',
#  'Which notification first made changes to the naming of regions in the context of this passage?',
#  'When did the provisions of the CMPF Scheme come into force for coal mines in West Bengal and Bihar?',
#  'Which areas were included under the CMPF Scheme in Bihar on May 12, 1947?',
#  'What is the effective date of the CMPF Scheme for coal mines in the Central Provinces and Berar?',
#  'Which coal mines in Maharashtra were excluded from the CMPF Scheme effective January 1, 1957?',
#  "What date marks the CMPF Scheme's applicability to coal mines in the state of Nagaland?",
#  'Which government notification reconstituted the subparagraph mentioned in the passage?',
#  'When was the term "New State of Bombay" replaced, and what was it substituted with?',
#  'Did the CMPF Scheme apply to all coal mines in the Central Provinces and Odisha, or only specific ones?',
#  'What territories were mentioned as comprising the "New State of Bombay" before it was renamed?',
#  'What is the significance of January 1, 1957, in the context of the CMPF Scheme?',
#  'What is the date of the S.R.O. that inserted this clause?',
#  'When did the provisions of the CMPF Scheme come into force for the Sasti Coal Mine?',
#  'To which coal mine does this clause specifically pertain in the passage?',
#  'Where can information about the extension of the CMPF Scheme to Assam be found?',
#  'Which appendix contains details about the extension of the CMPF Scheme to Talcher?',
#  'What are the states mentioned in Appendix III for the CMPF Scheme extension?',
#  'Which appendix should be referred to for the extension of the CMPF Scheme to Jammu and Kashmir (J&K)?',
#  'What is the significance of December 1, 1957, in the context of the CMPF Scheme?',
#  'How many appendices are mentioned in the passage for the CMPF Scheme extensions?',
#  'What is the full form of CMPF as referred to in the passage?',
#  'What is the title of Paragraph 1?',
#  'What is the title of Paragraph 2?',
#  'What is the Act number of the Coal Mines Provident Fund and Miscellaneous Provisions',
#  'Is the passage describing a contemporary or historical legislative act?',
#  'What does "Basic Wages" mean?',
#  'Are overtime payments included in "Basic Wages"?',
#  'Do "Basic Wages" include allowances for house rent?',
#  'Can "Basic Wages" include earnings while on leave with pay?',
#  'Are payments for food concession part of "Basic Wages"?',
#  'Is a bonus considered part of "Basic Wages"?',
#  'Are commissions included in the definition of "Basic Wages"?',
#  'If someone receives a present or donation, is it part of "Basic Wages"?',
#  'Do "Basic Wages" include earnings during active duty?',
#  'Are dearness allowances considered part of "Basic Wages"?',
#  'What does "Board" refer to in the passage?',
#  'Under which section of the Act is the Board of Trustees constituted?',
#  'What term is used to describe the Board of Trustees in this passage?',
#  'Is the Board described in the passage a general or specific entity?',
#  'What section number is mentioned in the passage in connection with the Board?',
#  'Does the passage specify who constitutes the Board?',
#  'Which section of the Act establishes the definition of the "Board"?',
#  'What does the term "Children" mean in the passage?',
#  'Does the definition of "Children" include adopted children?',
#  'What type of children are explicitly mentioned as part of the definition of "Children"?',
#  'What condition must be satisfied for adopted children to be included under "Children"?',
#  'Who determines whether the adoption of a child is legally recognized under the member’s personal law?',
#  'Does the definition of "Children" automatically include all adopted children?',
#  'Is there any mention of illegitimate children in the definition of "Children"?',
#  'What role does personal law play in the inclusion of adopted children in the definition of "Children"?',
#  'Can adopted children be included if the commissioner is not satisfied about the legal recognition of adoption?',
#  'Is the commissioner’s satisfaction based on any specific law?',
#  'Who does the term "Commissioner" refer to in the passage?',
#  'Under which section of the Act is the Commissioner appointed?',
#  'Which subsection of Section 3-C is referenced for the appointment of the Commissioner?',
#  'What legislative document governs the appointment of the Commissioner?',
#  'Is the Commissioner’s role determined under a general provision or a specific subsection?',
#  'What is the purpose of mentioning subsection (1) of Section 3-C in the definition of the Commissioner?',
#  'Who is considered an "Excluded Employee"? ',
#  'What are the reasons an employee can withdraw their Fund accumulation? ',
#  'Does working in a coal mine exclude an employee from the Fund? ',
#  'What kind of incapacity qualifies an employee for exclusion? ',
#  'Are laborers employed by contractors excluded from the Fund? ',
#  'At what age can an employee retire and be excluded from the Fund? ',
#  'Does the National Coal Development Corporation Ltd. provide pension benefits under specific conditions?',
#  'What happens if an employee withdraws their accumulation in part? ',
#  'Are employees under conditions similar to Railway establishments excluded from the Fund? ',
#  'Is the proviso to Para 2(g)(ii) still applicable? ',
#  'Who is included in the "family" of a male member? ',
#  'Can a male member exclude his wife from his family under this scheme? ',
#  'Who is included in the "family" of a female member? ',
#  'Can a female member exclude her husband from her family under this scheme? ',
#  "What happens if a child or a deceased son's child is adopted by someone else? ",
#  'Are dependent parents included in the family of both male and female members? ',
#  'Can the definition of "family" change over time for a member? ',
#  'Are adopted children always considered part of a member’s family? ',
#  'When were the definitions of "family" for male and female members updated? ',
#  'What is the role of the commissioner in determining family members? ']

# %%
# Create a DataFrame to hold query and metadata
query_data = pd.DataFrame({
    "query": queries,
    "chunk_char_count": [len(query) for query in queries],
    "chunk_word_count": [len(query.split()) for query in queries],
    "chunk_token_count": [len(query) // 4 for query in queries]  # Approx 4 chars per token
})

# %%
query_data
# Out:
#                                                  query  chunk_char_count  \
# 0    To which regions does the Coal Mines Provident...                65
# 1    Under which act is the Coal Mines Provident Fu...                65
# 2    What legal provision facilitates the applicati...                89
# 3    Does the scheme include coal mines in partiall...                63
# 4    Which provinces are explicitly mentioned as be...               101
# ..                                                 ...               ...
# 97   Are dependent parents included in the family o...                78
# 98   Can the definition of "family" change over tim...                62
# 99   Are adopted children always considered part of...                66
# 100  When were the definitions of "family" for male...                75
# 101  What is the role of the commissioner in determ...                68
#
#      chunk_word_count  chunk_token_count
# 0                  11                 16
# 1                  11                 16
# 2                  13                 22
# 3                  10                 15
# 4                  15                 25
# ..                ...                ...
# 97                 13                 19
# 98                 11                 15
# 99                 10                 16
# 100                12                 18
# 101                11                 17
#
# [102 rows x 4 columns]

# %%
# Create embeddings for all queries
print("[INFO] Generating embeddings for queries...")
query_data["embedding"] = list(tqdm(embedding_model.encode(queries, batch_size=32, show_progress_bar=True)))
# Out:
# [INFO] Generating embeddings for queries...
# Batches: 100%|██████████| 4/4 [00:03<00:00,  1.11it/s]
# 100%|██████████| 102/102 [00:00<?, ?it/s]

# %%
query_data
# Out:
#                                                  query  chunk_char_count  \
# 0    To which regions does the Coal Mines Provident...                65
# 1    Under which act is the Coal Mines Provident Fu...                65
# 2    What legal provision facilitates the applicati...                89
# 3    Does the scheme include coal mines in partiall...                63
# 4    Which provinces are explicitly mentioned as be...               101
# ..                                                 ...               ...
# 97   Are dependent parents included in the family o...                78
# 98   Can the definition of "family" change over tim...                62
# 99   Are adopted children always considered part of...                66
# 100  When were the definitions of "family" for male...                75
# 101  What is the role of the commissioner in determ...                68
#
#      chunk_word_count  chunk_token_count  \
# 0                  11                 16
# 1                  11                 16
# 2                  13                 22
# 3                  10                 15
# 4                  15                 25
# ..                ...                ...
# 97                 13                 19
# 98                 11                 15
# 99                 10                 16
# 100                12                 18
# 101                11                 17
#
#                                              embedding
# 0    [-0.041524656, -0.049773205, -0.02330386, 0.01...
# 1    [-0.043123186, -0.053074803, -0.008909841, 0.0...
# 2    [-0.024936039, -0.049957406, 0.0071940823, 0.0...
# 3    [-0.029753016, -0.029991096, -0.017820057, 0.0...
# 4    [-0.034144644, -0.045873385, -0.011126724, 0.0...
# ..                                                 ...
# 97   [-0.002607187, -0.035035748, -0.012603954, 0.0...
# 98   [-0.0029405584, 0.025271261, -0.024342898, 0.0...
# 99   [0.003107446, -0.05670504, 0.007287529, 0.0399...
# 100  [0.017903931, -0.014754101, -0.005228826, -0.0...
# 101  [0.041185148, -0.007107072, -0.017345421, 0.00...
#
# [102 rows x 5 columns]

# %%
# Save the DataFrame as csv
output_path = "queries_with_embeddings.csv"
query_data.to_csv(output_path, index=False)
print(f"[INFO] Query embeddings saved to {output_path}")
# Out:
# [INFO] Query embeddings saved to queries_with_embeddings.csv

# %%
import torch
from sentence_transformers import util

# Semantic Search Function
def semantic_search(query, query_data, embedding_model, top_k=5):
    # Embed the input query
    query_embedding = embedding_model.encode(query, convert_to_tensor=True)
    
    # Extract stored embeddings
    stored_embeddings = torch.tensor(query_data["embedding"].tolist(), dtype=torch.float32)
    
    # Compute dot product scores
    scores = util.dot_score(query_embedding, stored_embeddings)[0]
    
    # Get the top-k results
    top_results = torch.topk(scores, k=top_k)
    
    # Display the top results
    print(f"Query: {query}\n")
    for score, idx in zip(top_results.values, top_results.indices):
        # Use .item() to convert idx tensor to integer (as in your notebook)
        result_query = query_data.iloc[idx.item()]["query"]
        print(f"Score: {score:.4f}\nQuery: {result_query}\n")

# %%
# Example Usage
input_query = "What is the purpose of the Coal Mines Provident Fund?"
semantic_search(input_query, query_data, embedding_model, top_k=5)
# Out:
# Query: What is the purpose of the Coal Mines Provident Fund?
#
# Score: 0.8600
# Query: What is the purpose of the Coal Mines Provident Fund and Miscellaneous Provisions Act, 1948, in this context?
#
# Score: 0.8304
# Query: What legal provision facilitates the application of the Coal Mines Provident Fund Scheme?
#
# Score: 0.8144
# Query: Under which act is the Coal Mines Provident Fund Scheme governed?
#
# Score: 0.7937
# Query: To which regions does the Coal Mines Provident Fund Scheme apply?
#
# Score: 0.7884
# Query: Which act is cited in the passage as governing the provident fund scheme for coal mines?
